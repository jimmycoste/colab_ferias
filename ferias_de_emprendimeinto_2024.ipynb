# %% [markdown]
# <a href="https://colab.research.google.com/github/jimmycoste/colab_ferias/blob/main/ferias_de_emprendimeinto_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **¿Cuáles estudiantes han sido impactados por las ferias de emprendimiento en el año escolar 2023-2024 a nivel nacional?**
#
# Estoy realizando un estudio de tipo investigación evaluativa y descriptiva sobre las Ferias Técnicas o de Emprendimiento que se realizan en los Politécnicos de Secundaria Técnica en la República Dominicana. El objetivo principal de mi investigación es responder a la pregunta: ***¿Cuáles estudiantes han sido impactados por las ferias de emprendimiento realizadas a nivel nacional en el año escolar 2023-2024?***
#
#
# ---
#
#
# Jimmy R. Coste Yost
#
# Científico de datos de la Educación y Formación Técnico Profesional, Junio 2024
#
#
# ---
#
#
# ![Selección_1594.png](data:image/png;base64,...)

# %% [markdown]
# ## Objetivos de la Investigación
# **Investigación Evaluativa:**
#
# *   Evaluar el impacto de las Ferias Técnicas o de Emprendimiento en los estudiantes de los Politécnicos.
# *   Determinar la efectividad de estas ferias en términos de participación y resultados obtenidos por los estudiantes.
#
# **Investigación Descriptiva:**
#
# *   Describir la situación actual de las Ferias Técnicas o de Emprendimiento en los Politécnicos.
# *   Recopilar datos sobre la realización de ferias (si se llevarán a cabo y en qué fechas), así como la relación de estos eventos con la oferta técnica y la matrícula de los estudiantes.
#
# ## Tipo de estudio
#
# **Observacional:**
#
# Este estudio se caracteriza por observar y recopilar datos sin intervenir o manipular activamente las variables de estudio. En este caso, se observa y analiza la relación entre la realización de ferias técnicas o de emprendimiento en los Politécnicos de la Secundaria Técnica y la participación directa de los estudiantes de la Educación Técnico Profesional en la República Dominicana.
#
# ## Metodología
#
# Para llevar a cabo este estudio, seguiré estos pasos:
#
# **Recolección de Datos:**
#
# *   Realizar encuestas a los Politécnicos para obtener información sobre si tendrán feria este año y en qué fecha.
# *   Obtener datos del Sistema de Información (SIGERD) sobre la oferta técnica y matrícula de los Politécnicos.
#
# **Análisis de Datos:**
#
# *   Cruzar la información recopilada para determinar cuáles estudiantes han sido impactados por las ferias de emprendimiento.
# *   Realizar un análisis descriptivo de la frecuencia y distribución de las ferias a nivel nacional.
#
# ## Tipos de Datos
# **Cuantitativos:**
#
# *   Datos numéricos sobre matrícula y participación en las ferias.
# *   Estadísticas de la oferta técnica en los Politécnicos.
#
# **Cualitativos:**
#
# *   Información descriptiva sobre las fechas y realización de las ferias.
#
# ## Preguntas de Investigación
# *   ¿Cuántos Politécnicos realizarán ferias técnicas o de emprendimiento este año?
# *   ¿En qué fechas se llevarán a cabo estas ferias?
# *   ¿Cuál es la matrícula y la oferta técnica de los Politécnicos que realizarán ferias?
# *   ¿Cuál es la proporción del impacto de las ferias de emprendimiento en los politécnicos y sus estudiantes de secundaria técnica a nivel nacional?
#
# ## Resultados Esperados
# Espero identificar qué Politécnicos están llevando a cabo ferias, las fechas en que se realizan, y cómo estos eventos están afectando a los estudiantes en términos de participación y desarrollo de habilidades. También busco entender la relación entre la oferta técnica de los Politécnicos y la participación en las ferias.
#
# ## Incorporación de Información en el Estudio
# Toda esta información será recopilada, analizada y presentada en mi estudio para ofrecer una visión comprensiva del estado actual y el impacto de las Ferias Técnicas o de Emprendimiento en los Politécnicos de Secundaria Técnica en la República Dominicana. Este enfoque me permitirá evaluar de manera efectiva cómo estas ferias están beneficiando a los estudiantes y qué mejoras podrían implementarse en el futuro.

# %% [markdown]
# ## **Estableciendo el ambiente.**
#
# ## Librerias
# En el lenguaje de programación python, importo las liberias pandas y numpy para manipulación de datos y posterior analisis.
#
# Importo además las liberias matplotlib y seaborn para visualización de los resultados ecnontrados.

# %%
# Importar librerias

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
import os

# %% [markdown]
# ## Carga de datos
#
# Para la carga de los datos y la creacción de los *dataframes* procedo a montar el Google Drive donde están alojados los archivos delimitados por coma (csv), listar los archivos en la ruta especificada y cargar los datos necesarios para el análisis.

# %%
# Montar Google Drive
drive.flush_and_unmount()
# Ensure a clean mount
drive.mount('/content/drive/')

# Definir las rutas de los archivos
ferias_dir = '/content/drive/MyDrive/2024_Ferias_emprendimiento'

# Verify the correct path in your Google Drive
ferias_path = os.path.join(ferias_dir, '20240612_FERIAS_EMPRENDIMIENTO.csv')
matricula_etp_path = os.path.join(ferias_dir, '20240612_matricula_etp.csv')
matricula_oferta_etp_path = os.path.join(ferias_dir, '20240612_matricula_oferta_etp 1(in).csv')

# List files in the directory to verify the file exists and the path is correct
# !ls '{ferias_dir}'

# Cargar los archivos CSV
ferias_emprendimiento_df = pd.read_csv(ferias_path)
matricula_etp_df = pd.read_csv(matricula_etp_path)
matricula_oferta_etp_df = pd.read_csv(matricula_oferta_etp_path, encoding='latin-1') # Try 'latin-1' encoding
# Out:
# Mounted at /content/drive/
#  20240612_FERIAS_EMPRENDIMIENTO.csv  '20240612_matricula_oferta_etp 1(in).csv'
#  20240612_matricula_etp.csv	     'Cuadernillo DETP_Ferias_web.pdf'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Análisis**
#
# **Preguntas:**
#
# ### ¿Cuántos politécnicos realizaron ferias de emprendimiento en el año escolar 2023-2024?
# ### ¿Cual es la proporción de politécnicos que realizaron ferias de emprendimiento en el año escolar 2023-2024?

# %%
# Filtro politécnicos que realizarán ferias
ferias_realizaran_df = ferias_emprendimiento_df.dropna(subset=['FECHA_FERIA\n'])

# Número de politécnicos que realizarán ferias
num_politecnicos_ferias = ferias_realizaran_df['CENTRO'].nunique()

# Total de politécnicos
num_total_politecnicos = matricula_etp_df['POLITÉCNICO'].nunique()

# Proporción de politécnicos que realizarán ferias
proporcion_ferias = num_politecnicos_ferias / num_total_politecnicos

# Mostrar los resultados
print(f"Número de politécnicos que realizarán ferias: {num_politecnicos_ferias}")
print(f"Total de politécnicos: {num_total_politecnicos}")
print(f"Proporción de politécnicos que realizarán ferias: {proporcion_ferias:.2%}")
# Out:
# Número de politécnicos que realizarán ferias: 119
# Total de politécnicos: 358
# Proporción de politécnicos que realizarán ferias: 33.24%

# %%
# Etiquetas de los sectores
labels = ['Politécnicos con ferias', 'Politécnicos sin ferias']

# Tamaños de los sectores
sizes = [num_politecnicos_ferias, num_total_politecnicos - num_politecnicos_ferias]

# Colores de los sectores
colors = ["#00ffcc","#ff9900"]

# Crear el código pastel
plt.figure(figsize=(5, 5))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('Proporción de politécnicos que participan en ferias')
plt.show()

# %% [markdown]
# Con base en los datos proporcionados sobre el número y la proporción de politécnicos que realizarán ferias de emprendimiento, podemos llegar a varias conclusiones objetivas:
#
# **Alcance de las Ferias de Emprendimiento:**
#
# **Número absoluto:** 119 politécnicos realizarán ferias de emprendimiento este año. Este número indica una participación significativa en actividades de fomento del emprendimiento y de técnicas aplicadas dentro del sistema educativo.
#
# **Proporción:** Aproximadamente el 33.24% de los politécnicos del país estarán involucrados en la organización de estas ferias. Esto significa que aproximadamente uno de cada tres politécnicos está comprometido con la promoción del emprendimiento entre sus estudiantes.

# %% [markdown]
# **Pregunta:**
#
# ### ¿En qué fechas se llevarán a cabo estas ferias?

# %%
# Convertir el campo "FECHA_FERIA" a formato de fecha
ferias_emprendimiento_df['FECHA_FERIA\n'] = pd.to_datetime(ferias_emprendimiento_df['FECHA_FERIA\n'], format='%m/%d/%Y')

# Extraer el mes y el año de "FECHA_FERIA"
ferias_emprendimiento_df['MES'] = ferias_emprendimiento_df['FECHA_FERIA\n'].dt.month
ferias_emprendimiento_df['AÑO'] = ferias_emprendimiento_df['FECHA_FERIA\n'].dt.year

# Contar la cantidad de ferias por mes
ferias_por_mes = ferias_emprendimiento_df.groupby(['AÑO', 'MES']).size().reset_index(name='CANTIDAD_FERIAS')

# Mostrar los resultados
print("Cantidad de ferias por mes:")
print(ferias_por_mes)
# Out:
# Cantidad de ferias por mes:
#     AÑO  MES  CANTIDAD_FERIAS
# 0  2024    1                1
# 1  2024    3                7
# 2  2024    4               42
# 3  2024    5               59
# 4  2024    6                9
# 5  2024    9                1

# %%
# Grafico de linea

sns.lineplot(data=ferias_por_mes, x='MES', y='CANTIDAD_FERIAS')
# Out:
# <Axes: xlabel='MES', ylabel='CANTIDAD_FERIAS'>

# %% [markdown]
# Con los resultados obtenidos de la cantidad de ferias por mes, podemos llegar a varias conclusiones:
#
# **Estacionalidad de las ferias de emprendimiento:**
#
# El mes con la mayor cantidad de ferias es mayo, seguido de abril. Esto puede indicar que hay una estacionalidad en la realización de las ferias de emprendimiento, con un pico de actividades en primavera, en donde se está en la antesala del fin de año escolar para los estudiantes Agosto - Junio.
#
# **Necesidad de investigación adicional:**
#
# La única feria registrada en enero y otra única realizada en septiembre podría ser un punto de interés para investigaciones adicionales. ¿Por qué solo hay una feria en enero? ¿Hay algún motivo específico para realizar la feria en ese mes? ¿Y porqué realizar una feria en septiembre, recien iniando el año escolar?

# %% [markdown]
# **Preguntas:**
#
# ### ¿Cuál es la matrícula y la oferta técnica de los Politécnicos que realizarán ferias?
# ### ¿Cuál es la proporción del impacto de las ferias de emprendimiento en los politécnicos y sus estudiantes de secundaria técnica a nivel nacional?

# %%
# Obtener la matrícula de los politécnicos que realizarán ferias
matricula_ferias_df = matricula_etp_df[matricula_etp_df['SIGERD'].isin(ferias_realizaran_df['SIGERD'])]

# Calcular la matrícula total de estudiantes que participan en las ferias
matricula_total_ferias = matricula_ferias_df['MATRÍCULA'].sum()

# Calcular la matrícula total de estudiantes
matricula_total_etp = matricula_etp_df['MATRÍCULA'].sum()

# Calcular la proporción de estudiantes que participan en las ferias
proporcion_matricula_ferias = matricula_total_ferias / matricula_etp_df['MATRÍCULA'].sum()

# Mostrar los resultados
print(f"Matrícula total de estudiantes en el año escolar 2023-2024: {matricula_total_etp}")
print(f"Matrícula total de estudiantes que participan en las ferias: {matricula_total_ferias}")
print(f"Proporción de estudiantes que participan en las ferias: {proporcion_matricula_ferias:.2%}")
# Out:
# Matrícula total de estudiantes en el año escolar 2023-2024: 92275
# Matrícula total de estudiantes que participan en las ferias: 31886
# Proporción de estudiantes que participan en las ferias: 34.56%

# %%
# prompt: generar una visualizaión de pastel con seaborn para esta propoción

import seaborn as sns

# Create a pie chart
labels = ["Estudiantes participando", "Estudiantes no participando"]
sizes = [matricula_total_ferias, matricula_total_etp - matricula_total_ferias]
colors = ["#00ffcc","#ff9900"]

plt.pie(sizes, labels=labels, colors=colors, autopct="%1.1f%%")
plt.title("Proporción de Estudiantes Participantes en Ferias")
plt.show()

# %% [markdown]
# Relacionando los datos de la matrícula total de estudiantes y los estudiantes que participan en las ferias de emprendimiento, podemos llegar a varias conclusiones objetivas:
#
# **Participación Estudiantil:**
#
# **Número absoluto:** 31,886 estudiantes están participando en las ferias de emprendimiento. Este es un número considerable que refleja el alcance de las ferias dentro del sistema educativo técnico profesional.
#
# **Proporción:** Aproximadamente el 34.56% de los estudiantes están participando en las ferias. Esto muestra que más de un tercio de los estudiantes están involucrados en actividades de emprendimiento, lo cual es una proporción significativa.
#
# **Comparación con la Proporción de Politécnicos:**
#
# La proporción de politécnicos que organizan ferias es del 33.24%, lo que es ligeramente menor que la proporción de estudiantes que participan (34.56%). Esto indica que los politécnicos que organizan ferias pueden tener una matrícula ligeramente mayor que el promedio o que hay una alta participación de estudiantes en los politécnicos que sí organizan ferias.

# %% [markdown]
# **Pregunta:**
#
# ### ¿Cuáles son las Regionales y Distritos Educativos con mayor cantidad de Politécnicos que realizan las ferias de Emrprendimeinto?
#
# ### ¿Cuáles son las Regionales y Distritos Educativos con mayor cantidad de estudiantes participantes en las ferias de Emrprendimeinto?

# %%
    # Filtrar politécnicos que tienen definida una fecha para la feria
    ferias_filtradas_df = ferias_emprendimiento_df[ferias_emprendimiento_df['FECHA_FERIA\n'].notna()]

    # Obtener el conteo de politécnicos por regional
    regionales_count = ferias_filtradas_df['REGIONAL\n'].value_counts().head(7)

    # Obtener el conteo de politécnicos por distrito educativo
    distritos_count = ferias_filtradas_df['DISTRITO'].value_counts().head(4)

    # Mostrar los resultados
    print("Las 7 Regionales con mayor cantidad de Politécnicos que realizan ferias de emprendimiento:")
    print(regionales_count)

    print("\nLos 4 Distritos Educativos con mayor cantidad de Politécnicos que realizan ferias de emprendimiento:")
    print(distritos_count)

    # Prepare the data for the bar plot
regionales_data = regionales_count.to_frame().reset_index()
regionales_data.columns = ['Regionales', 'Politécnicos']

distritos_data = distritos_count.to_frame().reset_index()
distritos_data.columns = ['Distritos', 'Politécnicos']

# Create the bar plot for regionales
plt.figure(figsize=(10, 6))
sns.barplot(x='Politécnicos', y='Regionales', data=regionales_data)
plt.title('Top 7 Regionales con más Politécnicos en Ferias')
plt.xlabel('Número de Politécnicos')
plt.ylabel('Regionales')
plt.show()

# Create the bar plot for distritos
plt.figure(figsize=(10, 6))
sns.barplot(x='Politécnicos', y='Distritos', data=distritos_data)
plt.title('Top 4 Distritos con más Politécnicos en Ferias')
plt.xlabel('Número de Politécnicos')
plt.ylabel('Distritos Educativos')
plt.show()
# Out:
# Las 7 Regionales con mayor cantidad de Politécnicos que realizan ferias de emprendimiento:
# REGIONAL\n
# 10 SANTO DOMINGO               21
# 08 SANTIAGO                    17
# 07 SAN FRANCISCO DE MACORIS    11
# 15 SANTO DOMINGO               11
# 18 BAORUCO                     10
# 06 LA VEGA                      9
# 11 PUERTO PLATA                 8
# Name: count, dtype: int64
#
# Los 4 Distritos Educativos con mayor cantidad de Politécnicos que realizan ferias de emprendimiento:
# DISTRITO
# 0805 - SANTIAGO CENTRO-OESTE    6
# 0803 - SANTIAGO SUR-ESTE        5
# 1002 - SABANA PERDIDA           5
# 1804 - JIMANI                   5
# Name: count, dtype: int64

# %% [markdown]
# Basándome en las conclusiones obtenidas a partir de los datos proporcionados, podemos observar un claro patrón de fuerte participación y compromiso de los estudiantes en las actividades de emprendimiento en la República Dominicana.
#
# La Regional 10 de Santo Domingo encabeza la lista con una cantidad significativa de 6932 estudiantes participantes en ferias de emprendimiento, seguida por la Regional 08 de Santiago con 5654 estudiantes. La segunda presencia de Santo Domingo en la lista, la Regional 15 con 4534 estudiantes, subraya aún más el apoyo y el interés al emprendimiento en la región capitalina.
#
# En cuanto a los distritos educativos, Sabana Perdida lidera con 2467 estudiantes participantes, seguido por Santiago Centro-Oeste con 2026 y Santiago Sur-Este con 2013. Estos resultados sugieren un ambiente propicio para el desarrollo de habilidades emprendedoras y la promoción de la cultura empresarial en estas áreas.
#
# En general, la amplia participación y el compromiso demostrados por los estudiantes en las ferias de emprendimiento indican un creciente interés y apoyo a las actividades de emprendimiento en la República Dominicana, lo que podría tener un impacto positivo en el fomento del espíritu empresarial y el desarrollo económico del país.

# %%
# prompt: ¿Cuáles son las Regionales y Distritos Educativos con mayor cantidad de estudiantes participantes en las ferias de Emrprendimeinto?

# Obtener el conteo de estudiantes participantes por regional
regionales_estudiantes_count = matricula_ferias_df.groupby('REGIONAL')['MATRÍCULA'].sum().sort_values(ascending=False).head(7)

# Obtener el conteo de estudiantes participantes por distrito educativo
distritos_estudiantes_count = matricula_ferias_df.groupby('DISTRITO')['MATRÍCULA'].sum().sort_values(ascending=False).head(4)

# Mostrar los resultados
print("Las 7 Regionales con mayor cantidad de estudiantes participantes en ferias de emprendimiento:")
print(regionales_estudiantes_count)

print("\nLos 4 Distritos Educativos con mayor cantidad de estudiantes participantes en ferias de emprendimiento:")
print(distritos_estudiantes_count)

# Prepare the data for the bar plot
regionales_estudiantes_data = regionales_estudiantes_count.to_frame().reset_index()
regionales_estudiantes_data.columns = ['Regionales', 'Estudiantes']

distritos_estudiantes_data = distritos_estudiantes_count.to_frame().reset_index()
distritos_estudiantes_data.columns = ['Distritos', 'Estudiantes']

# Create the bar plot for regionales
plt.figure(figsize=(10, 6))
sns.barplot(x='Estudiantes', y='Regionales', data=regionales_estudiantes_data)
plt.title('Top 7 Regionales con más Estudiantes en Ferias')
plt.xlabel('Número de Estudiantes')
plt.ylabel('Regionales')
plt.show()

# Create the bar plot for distritos
plt.figure(figsize=(10, 6))
sns.barplot(x='Estudiantes', y='Distritos', data=distritos_estudiantes_data)
plt.title('Top 4 Distritos con más Estudiantes en Ferias')
plt.xlabel('Número de Estudiantes')
plt.ylabel('Distritos Educativos')
plt.show()
# Out:
# Las 7 Regionales con mayor cantidad de estudiantes participantes en ferias de emprendimiento:
# REGIONAL
# 10 - SANTO DOMINGO               6932
# 08 - SANTIAGO                    5654
# 15 - SANTO DOMINGO               4534
# 07 - SAN FRANCISCO DE MACORIS    2237
# 11 - PUERTO PLATA                1941
# 06 - LA VEGA                     1638
# 16 - COTUI                       1536
# Name: MATRÍCULA, dtype: int64
#
# Los 4 Distritos Educativos con mayor cantidad de estudiantes participantes en ferias de emprendimiento:
# DISTRITO
# 1002 - SABANA PERDIDA           2467
# 0805 - SANTIAGO CENTRO-OESTE    2026
# 0803 - SANTIAGO SUR-ESTE        2013
# 1006 - MENDOZA                  1862
# Name: MATRÍCULA, dtype: int64

# %% [markdown]
# A partir de los datos proporcionados, se pueden extraer las siguientes conclusiones:
#
# **Regional 10 de Santo Domingo lidera en participación en ferias de emprendimiento:** Con 6932 estudiantes participantes, la Regional 10 de Santo Domingo demuestra un alto nivel de interés y compromiso hacia el emprendimiento entre los estudiantes. Este resultado sugiere un ambiente propicio para el desarrollo de habilidades empresariales en la región capitalina.
#
# **Importante participación en Santiago y San Francisco de Macorís:** Las regionales 08 de Santiago y 07 de San Francisco de Macorís ocupan el segundo y cuarto lugar, respectivamente, en la lista de participación en ferias de emprendimiento. Estos resultados indican un fuerte interés y apoyo hacia el emprendimiento en estas regiones.
#
# **Fuerte presencia en los distritos educativos de Sabana Perdida y Santiago Centro-Oeste:** Los distritos educativos 1002 de Sabana Perdida y 0805 de Santiago Centro-Oeste muestran una alta participación en ferias de emprendimiento, con 2467 y 2026 estudiantes respectivamente. Esto sugiere un ambiente favorable para el desarrollo de habilidades emprendedoras en estas áreas.
#
# **Interés creciente en Puerto Plata y La Vega:** Aunque ocupan lugares más bajos en la lista, las regionales 11 de Puerto Plata y 06 de La Vega muestran una participación significativa en ferias de emprendimiento. Este resultado sugiere un creciente interés y apoyo hacia el emprendimiento en estas regiones.
#
# En resumen, los datos reflejan un alto nivel de interés y compromiso hacia el emprendimiento entre los estudiantes en las regiones y distritos educativos mencionados, lo que podría tener un impacto positivo en el desarrollo de habilidades empresariales y la promoción de la cultura empresarial en la República Dominicana.

# %% [markdown]
# **Pregunta:**
#
# ### ¿Cuáles son las Familias Profesionales con mayor representación en las ferias de emprendimiento y cómo se distribuye la matrícula de estudiantes entre estas familias?

# %%
# Merge the dataframes on the common column 'SIGERD'
merged_df = pd.merge(ferias_emprendimiento_df, matricula_oferta_etp_df, on='SIGERD')

# Extract the Familia Profesional column
familia_profesional = merged_df['FAMILIA PROFESIONAL']

# Count the occurrences of each Familia Profesional
familia_profesional_count = familia_profesional.value_counts().sort_index()

# Get the matrícula for each Familia Profesional
matricula_familia_profesional = merged_df.groupby('FAMILIA PROFESIONAL')['MATRICULA'].sum()

# Create a DataFrame for the scatter plot
df_scatter = pd.DataFrame({
    'Familia Profesional': familia_profesional_count.index,
    'Ferias': familia_profesional_count.values,
    'Matricula': matricula_familia_profesional.values
})

print(df_scatter)

# Generate the scatter plot
plt.figure(figsize=(8, 8))
scatter_plot = sns.scatterplot(data=df_scatter, x='Ferias', y='Matricula', size='Matricula', hue='Familia Profesional', sizes=(70, 1000), alpha=0.7, palette='tab10')

# Añadir etiquetas y título
plt.title('Familias Profesionales con Mayor Presencia en Ferias', fontsize=16)
plt.xlabel('Número de Ferias', fontsize=14)
plt.ylabel('Total Matrícula', fontsize=14)
plt.legend(title='Familia Profesional', bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar el gráfico
plt.show()
# Out:
#                            Familia Profesional  Ferias  Matricula
# 0             ACTIVIDADES FÍSICAS Y DEPORTIVAS       1       62.0
# 1                    ADMINISTRACIÓN Y COMERCIO     122    11186.0
# 2                                      AGRARIA      10      760.0
# 3                     AUDIOVISUALES Y GRÁFICAS       6      532.0
# 4                       CONSTRUCCIÓN Y MINERÍA       1      154.0
# 5                   ELECTRICIDAD Y ELECTRÓNICA      40     2425.0
# 6           INDUSTRÍAS ALIMENTARIAS Y QUÍMICAS       4      211.0
# 7                 INFORMÁTICA Y COMUNICACIONES      86     8009.0
# 8                              MADERA Y MUEBLE       7      397.0
# 9                                        SALUD      39     3448.0
# 10                   SEGURIDAD Y MEDIOAMBIENTE       6      268.0
# 11  SERVICIOS SOCIOCULTURALES Y A LA COMUNIDAD       1      162.0
# 12                        TURISMO Y HOSTELERÍA      38     3210.0

# %% [markdown]
# A partir de los datos proporcionados sobre las ferias y la matrícula por familia profesional, se pueden llegar a varias conclusiones significativas:
#
# **Familias Profesionales Dominantes:**
#
# *Administración y Comercio* es la familia profesional con mayor cantidad de ferias (122) y también tiene la mayor matrícula (11,186). Esto sugiere que esta área es la más representada y probablemente una de las más participantes en el contexto de las ferias de emprendimiento.
#
# *Informática y Comunicaciones* es la segunda más representada, con 86 ferias y una matrícula de 8,009. Este dato indica una fuerte presencia y posiblemente una alta demanda por habilidades en tecnología y comunicaciones.
#
# **Otras Familias Profesionales con Alta Representación:**
#
# *Electricidad y Electrónica* tiene 40 ferias y una matrícula de 2,425.
# *Salud* también tiene una notable representación con 39 ferias y una matrícula de 3,448.
# *Turismo y Hostelería* cuenta con 38 ferias y una matrícula de 3,210.
#
# **Familias Profesionales Menos Representadas**:
#
# *Actividades Físicas y Deportivas, Construcción y Minería, y Servicios Socioculturales y a la Comunidad tienen solo una feria cada una, con matrículas de 62, 154 y 162, respectivamente.
#
# Industrías Alimentarias y Químicas y Audiovisuales y Gráficas tienen 4 y 6 ferias respectivamente, con matrículas relativamente bajas (211 y 532).
#
# **Proporción de Ferias y Matrícula:**
#
# Aunque algunas familias profesionales tienen menos ferias, sus matrículas pueden ser significativas en relación con el número de ferias. Por ejemplo, Salud tiene 39 ferias, pero una matrícula de 3,448, lo que indica un alto interés en las ferias dentro de esta familia.
#
# *Electricidad y Electrónica* tiene 40 ferias y una matrícula de 2,425, lo cual muestra un balance entre la cantidad de ferias y la cantidad de estudiantes.
#
# **Posibles Áreas de Mejora:**
#
# Agraria y Seguridad y Medioambiente tienen relativamente pocas ferias (10 y 6 respectivamente) y matrículas bajas en comparación con otras familias profesionales más dominantes.
# Podría ser beneficioso investigar si estas áreas requieren más promoción o recursos para aumentar su representación en las ferias.
# Construcción y Minería y Actividades Físicas y Deportivas también podrían beneficiarse de un mayor enfoque para incrementar su presencia en las ferias.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Alta Demanda en Áreas Específicas:** Las familias profesionales de Administración y Comercio, Informática y Comunicaciones, y Electricidad y Electrónica tienen una alta demanda, como lo indica su número de ferias y matrículas. Esto refleja las tendencias actuales del mercado laboral y las preferencias de los estudiantes.
#
# **Necesidad de Diversificación:** Hay una disparidad notable en la representación de las diferentes familias profesionales. Áreas como Actividades Físicas y Deportivas, Construcción y Minería, y Servicios Socioculturales y a la Comunidad tienen una representación muy baja. Esto sugiere una oportunidad para diversificar y equilibrar la oferta educativa y las oportunidades de feria.
#
# **Impacto en Políticas Educativas:** Los datos sugieren que podría ser beneficioso revisar las políticas y recursos destinados a las familias profesionales menos representadas para fomentar una mayor participación y equilibrio. Además, promover el desarrollo en áreas con alta demanda puede continuar apoyando las necesidades del mercado laboral.
#
# **Estrategias de Promoción y Apoyo:** Implementar estrategias para aumentar la visibilidad y el apoyo a las familias profesionales con menor representación en las ferias puede contribuir a un sistema educativo más equilibrado y inclusivo.
#
# **Inversión en Recursos:** Invertir en recursos para áreas con alta matrícula pero pocas ferias, y áreas con muchas ferias pero baja matrícula, puede optimizar el impacto de las ferias de emprendimiento en la formación técnica y profesional de los estudiantes.
#
# Estas conclusiones pueden ayudar a orientar futuras decisiones y políticas en el ámbito de la educación técnica profesional en la República Dominicana, asegurando un desarrollo equilibrado y una mayor inclusión de todas las áreas profesionales.

# %% [markdown]
# ---
#
# # Conclusiones
#
# A partir de los datos proporcionados sobre las ferias de emprendimiento en la República Dominicana, podemos extraer conclusiones significativas que reflejan el compromiso y la participación tanto de instituciones educativas como de estudiantes en el fomento del espíritu empresarial.
#
# La participación en las ferias de emprendimiento es notable, con un total de 119 politécnicos programando este tipo de eventos para el año en curso. Esta cifra indica un compromiso sustancial por parte de las instituciones educativas para cultivar habilidades empresariales entre los estudiantes.
#
# La estacionalidad de las ferias, con una concentración especialmente alta en los meses de mayo y abril, sugiere una planificación estratégica que coincide con el final del año escolar. Esto resalta la importancia de estas actividades como una forma efectiva de concluir el período académico.
#
# La alta participación estudiantil, con más de 31,000 estudiantes involucrados, representa un interés y compromiso significativos en las actividades relacionadas con el emprendimiento. Este nivel de participación subraya la importancia y la relevancia de las ferias de emprendimiento en el contexto educativo de la República Dominicana.
#
#
#
# Además de las conclusiones destacadas, hay oportunidades claras para mejorar la representación y la participación en las ferias de emprendimiento en la República Dominicana.
#
# En primer lugar, para aumentar la participación de los politécnicos en la organización de ferias de emprendimiento, se podrían implementar estrategias como programas de sensibilización y capacitación, la creación de redes de apoyo entre instituciones, incentivos y reconocimientos a nivel regional o nacional, asistencia técnica y provisión de recursos adicionales, así como promoción de la colaboración con empresas y organizaciones externas. Estas medidas podrían reducir las barreras y temores, ofrecer apoyo técnico y financiero, y fomentar una cultura emprendedora más sólida en el sistema educativo técnico profesional de la República Dominicana.
#
# Tambien es importante diversificar las áreas menos representadas, como Actividades Físicas y Deportivas, Construcción y Minería, y Servicios Socioculturales y a la Comunidad. Para lograrlo, se podría implementar un enfoque estratégico que incluya programas de promoción específicos, mayor disponibilidad de recursos y colaboración con empresas y organizaciones relacionadas con esas áreas.
#
# Asimismo, se puede aprovechar el interés y la participación existentes para expandir el alcance y la diversidad de las ferias de emprendimiento. Esto podría lograrse mediante la creación de programas de mentoría, talleres especializados y la incorporación de conferenciantes y emprendedores destacados en áreas menos representadas.
#
# Esta diversificación no solo enriquecería la experiencia de los estudiantes, sino que también promovería una cultura emprendedora más inclusiva y variada en el ámbito educativo de la República Dominicana, llegando de manera directa a esa comunidad circundante al Politécnico.

# %% [markdown]
# ## Definición de términos
#
# **Politécnico**
#
# En la República Dominicana, un politécnico es un centro educativo del nivel secundario que oferta la educación técnico profesional en más de un servicio de esta modalidad.
#
# **Oferta**
#
# Se refiere a los servicios ofertados en el Politécnico, digase, los *Titulos* o programas de *Bachilleratos técnicos* del Catálogo de Títulos de la Educación Técnico Profesional, debidamente implementados y con matrícula asignada.
#
# **Bachillerato Técnico**
#
# Diseño curricular para el segundo ciclo del nivel secundario en la modalidad técnico profesional, vinculado a perfiles profesionales y organizado por familias profesionales. Se recogen en el Catálogo de Títulos de la Educación Técnico Profesional. Tambien suele referirse a este como *Titulos* y constituye la oferta curricular de un politécnico, una vez está implementado y cuenta con matrícula asignada.
#
# **Feria de emprendimiento.**
#
# Una feria de emprendimiento es una actividad curricular que realiza un politécnico para mostrar mediante una propuesta realizable, diseñada y ejecutada por los estudiantes a partir de sus aprendizajes durante sus 3 años de educación y formación en la Educación Técnico Profesional, en sus respectivos titulos de Bachiller Técnico. Pueden participar estudiantes de los 3 grados, digase de 4to, 5to y 6to grado del segundo ciclo del nivel secundario.
#
# Las ferias técnicas o de emprendimiento, están orientadas a estimular los aprendizajes obtenidos en el transcurso de su formación técnica, estos aprendizajes se evidencian mediante el reconocimiento de competencias relativas al desarrollo de la acción emprendedora y la simulación de la creación de una micro empresa en el aula.
